# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsaxena/Python/blob/main/nlu_tut_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://setup.johnsnowlabs.com/nlu/colab.sh -O - | bash
# Out:
# --2022-01-03 06:43:03--  https://setup.johnsnowlabs.com/nlu/colab.sh
# Resolving setup.johnsnowlabs.com (setup.johnsnowlabs.com)... 51.158.130.125
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://raw.githubusercontent.com/JohnSnowLabs/nlu/master/scripts/colab_setup.sh [following]
# --2022-01-03 06:43:04--  https://raw.githubusercontent.com/JohnSnowLabs/nlu/master/scripts/colab_setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1662 (1.6K) [text/plain]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.62K  --.-KB/s    in 0s
#
# ...

# %% [markdown]
# # **Load**

# %%
import nlu
pipeline = nlu.load('sentiment')
pipeline.predict("I love this Documentation! It's so good!")
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                    document sentiment  sentiment_confidence
# 0  I love this Documentation! It's so good!       pos              0.999991

# %%
pipeline = nlu.load('emotion')
pipeline.predict("I love this Documentation! It's so good!")
# Out:
# classifierdl_use_emotion download started this may take some time.
# Approximate size to download 21.3 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#   emotion emotion_confidence_confidence                    sentence
# 0     joy                      0.979422  I love this Documentation!
# 0     joy                      0.979422               It's so good!

# %% [markdown]
# # **Configuring load module**
#
# To configure your model or pipeline, first load a NLU component and use the print_components() function.
# The print outputs tell you at which index of the pipe_components attribute which NLU component is located.
# Via setters which are named according to the parameter values a model can be configured

# %% [markdown]
# # **Output Parameters**
#
# NLU defines 4 output levels for the generated predictions.
# The output levels define how granular the predictions and outputs of NLU will be.
# Depending on what downstream tasks NLU will be used for the output level should be adjusted.
#
# 1. Token level: Outputs one row for every token in the input. One to many mapping.
# 2. Chunk level: Outputs one row for every chunk in the input. One to many mapping.
# 3. Sentence level: Outputs one row for every sentence the input. One to many mapping.
# 4. Document level output: Outputs one row for every document in the input. One to one mapping.
#
# NLU will try to infer the most useful output level automatically if an output level is not specified.
# The inferred output level will usually define the last element of the pipeline.

# %%
nlu.load('sentiment').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='document')
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                             document  ... sentiment_confidence
# 0  I love data science! It is so much fun! It can...  ...             0.999997
# 1                           I love the city New-York  ...             0.999998
#
# [2 rows x 3 columns]

# %%
nlu.load('sentiment').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='sentence')
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                   sentence sentiment sentiment_confidence
# 0                     I love data science!       pos                    1
# 0                       It is so much fun!       pos                    1
# 0  It can also be quite helpful to people.       pos                    1
# 1                 I love the city New-York       pos             0.999998

# %%
nlu.load('sentiment').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='chunk')
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                             document  ... sentiment_confidence
# 0  I love data science! It is so much fun! It can...  ...             0.999997
# 1                           I love the city New-York  ...             0.999998
#
# [2 rows x 3 columns]

# %%
nlu.load('sentiment').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='token')
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#   sentiment  sentiment_confidence     token
# 0       pos              0.999997         I
# 0       pos              0.999997      love
# 0       pos              0.999997      data
# 0       pos              0.999997   science
# 0       pos              0.999997         !
# 0       pos              0.999997        It
# 0       pos              0.999997        is
# 0       pos              0.999997        so
# 0       pos              0.999997      much
# 0       pos              0.999997       fun
# 0       pos              0.999997         !
# ...

# %%
nlu.load('pos').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='document')
# Out:
# pos_anc download started this may take some time.
# Approximate size to download 3.9 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#                                             document                                                pos
# 0  I love data science! It is so much fun! It can...  [PRP, VBP, NNS, NN, ., PRP, VBZ, RB, JJ, NN, ....
# 1                           I love the city New-York                            [PRP, VBP, DT, NN, NNP]

# %%
nlu.load('pos').predict(['I love data science! It is so much fun! It can also be quite helpful to people.', 'I love the city New-York'], output_level='token')
# Out:
# pos_anc download started this may take some time.
# Approximate size to download 3.9 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#    pos     token
# 0  PRP         I
# 0  VBP      love
# 0  NNS      data
# 0   NN   science
# 0    .         !
# 0  PRP        It
# 0  VBZ        is
# 0   RB        so
# 0   JJ      much
# 0   NN       fun
# 0    .         !
# 0  PRP        It
# 0   MD       can
# 0   RB      also
# 0   VB        be
# 0   RB     quite
# 0   JJ   helpful
# 0   TO        to
# 0  NNS    people
# 0    .         .
# 1  PRP         I
# 1  VBP      love
# 1   DT       the
# 1   NN      city
# 1  NNP  New-York

# %% [markdown]
# # **Position Parameters**
#
# By setting output_positions=True, the Dataframe generated by NLU will contain additional columns which describe the beginning and end of each feature inside of the original document. These additional _begining and _end columns let you infer the piece of the original input string that has been used to generate the output.
#
# 1. If the NLU output level is set to a different output level than some features output level, the resulting features will be inside of lists
# 2. If the NLU output level is set to the same output level as some feature, the generated positional features will be single integers
#
# Positional :
# 1. For token based components the positional features refer to the beginning and the end of the token inside of the original document the text originates from.
# 2. For sentence based components like sentence embeddings and different sentence classifiers the output of positional will describe the beginning and the end of the sentence that was used to generate the output.

# %%
nlu.load('sentiment').predict('I love data science!', output_level='token',  positions=True)
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#   document_begin document_end sentence_begin  ...    token token_begin token_end
# 0            [0]         [19]            [0]  ...        I           0         0
# 0            [0]         [19]            [0]  ...     love           2         5
# 0            [0]         [19]            [0]  ...     data           7        10
# 0            [0]         [19]            [0]  ...  science          12        18
# 0            [0]         [19]            [0]  ...        !          19        19
#
# [5 rows x 11 columns]

# %%
nlu.load('sentiment').predict('I love data science!', output_level='token',  positions=False)
# Out:
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
# sentence_detector_dl download started this may take some time.
# Approximate size to download 354.6 KB
# [OK!]
#   sentiment  sentiment_confidence    token
# 0       pos                   1.0        I
# 0       pos                   1.0     love
# 0       pos                   1.0     data
# 0       pos                   1.0  science
# 0       pos                   1.0        !

# %%
nlu.load('lang').predict('I love data science!', output_level='document')
# Out:
# detect_language_375 download started this may take some time.
# Approx size to download 9.4 MB
# [OK!]
#                document language_results  meta_language_confidence
# 0  I love data science!               en                  0.554421

# %%
nlu.load('lang').predict('python ਵਿੱਚ ਤੁਹਾਡਾ ਸੁਆਗਤ ਹੈ')
# Out:
# detect_language_375 download started this may take some time.
# Approx size to download 9.4 MB
# [OK!]
#   language_results  meta_language_confidence                     sentence
# 0               pa                       1.0  python ਵਿੱਚ ਤੁਹਾਡਾ ਸੁਆਗਤ ਹੈ

# %%
nlu.load('lang').predict('python ਵਿੱਚ ਤੁਹਾਡਾ ਸੁਆਗਤ ਹੈ', output_level='sentence')
# Out:
# detect_language_375 download started this may take some time.
# Approx size to download 9.4 MB
# [OK!]
#   language_results  meta_language_confidence                     sentence
# 0               pa                       1.0  python ਵਿੱਚ ਤੁਹਾਡਾ ਸੁਆਗਤ ਹੈ

# %%
nlu.load('lang').predict('ਭਾਰਤ ਵਿੱਚ ਸੁਆਗਤ ਹੈ; Welcome to India; भारत में तुम्हारा स्वागत है', output_level='sentence')
# Out:
# detect_language_375 download started this may take some time.
# Approx size to download 9.4 MB
# [OK!]
#   language_results  meta_language_confidence                      sentence
# 0               pa                  0.333333           ਭਾਰਤ ਵਿੱਚ ਸੁਆਗਤ ਹੈ;
# 0               pa                  0.333333             Welcome to India;
# 0               pa                  0.333333   भारत में तुम्हारा स्वागत है

# %%
pipe=nlu.load('lang sentiment pos ner')
data =''''ਭਾਰਤ ਵਿੱਚ ਸੁਆਗਤ ਹੈ. 
Welcome to India.
भारत में तुम्हारा स्वागत है. '''
df = pipe.predict(data, output_level='sentence')
df
# Out:
# detect_language_375 download started this may take some time.
# Approx size to download 9.4 MB
# [OK!]
# sentimentdl_glove_imdb download started this may take some time.
# Approximate size to download 8.7 MB
# [OK!]
# pos_anc download started this may take some time.
# Approximate size to download 3.9 MB
# [OK!]
# onto_recognize_entities_sm download started this may take some time.
# Approx size to download 160.1 MB
# [OK!]
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]
#   language_results  meta_language_confidence  ... sentiment sentiment_confidence
# 0               pa                  0.333333  ...       neg             0.926267
# 0               pa                  0.333333  ...       neg             0.926267
# 0               pa                  0.333333  ...       neg             0.926267
#
# [3 rows x 6 columns]
